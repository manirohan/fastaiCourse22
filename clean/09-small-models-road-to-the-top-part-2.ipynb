# %%
# install fastkaggle if not available
try: import fastkaggle
except ModuleNotFoundError:
    # !pip install -Uq fastkaggle

from fastkaggle import *

# %% [markdown]
# ## Going faster

# %%
comp = 'paddy-disease-classification'
path = setup_comp(comp, install='fastai "timm>=0.6.2.dev0"')
from fastai.vision.all import *
set_seed(42)
# Out:
# Downloading paddy-disease-classification.zip to /Users/rohan.ma/Desktop/local/Rohan_personal/my_git_repos/fastaiCourse22/clean
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1.02G/1.02G [01:07<00:00, 16.2MB/s]

# %%
trn_path = Path('sml')

# %%
resize_images(path/'train_images', dest=trn_path, max_size=256, recurse=True)

# %%
dls = ImageDataLoaders.from_folder(trn_path, valid_pct=0.2, seed=42,
    item_tfms=Resize((256,192)))

dls.show_batch(max_n=3)

# %%
def train(arch, item, batch, epochs=5):
    dls = ImageDataLoaders.from_folder(trn_path, seed=42, valid_pct=0.2, item_tfms=item, batch_tfms=batch)
    learn = vision_learner(dls, arch, metrics=error_rate).to_fp16()
    learn.fine_tune(epochs, 0.01)
    return learn

# %%
learn = train('resnet26d', item=Resize(192),
              batch=aug_transforms(size=128, min_scale=0.75))
# Out:
# Could not do one pass in your dataloader, there is something wrong in it. Please see the stack trace below:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 learn = train('resnet26d', item=Resize(192),
#       2               batch=aug_transforms(size=128, min_scale=0.75))
#
# Cell In[6], line 2, in train(arch, item, batch, epochs)
#       1 def train(arch, item, batch, epochs=5):
# ----> 2     dls = ImageDataLoaders.from_folder(trn_path, seed=42, valid_pct=0.2, item_tfms=item, batch_tfms=batch)
#       3     learn = vision_learner(dls, arch, metrics=error_rate).to_fp16()
#       4     learn.fine_tune(epochs, 0.01)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/data.py:125, in ImageDataLoaders.from_folder(cls, path, train, valid, valid_pct, seed, vocab, item_tfms, batch_tfms, img_cls, **kwargs)
#     118 get_items = get_image_files if valid_pct else partial(get_image_files, folders=[train, valid])
#     119 dblock = DataBlock(blocks=(ImageBlock(img_cls), CategoryBlock(vocab=vocab)),
#     120                    get_items=get_items,
#     121                    splitter=splitter,
#     122                    get_y=parent_label,
#     123                    item_tfms=item_tfms,
#     124                    batch_tfms=batch_tfms)
# --> 125 return cls.from_dblock(dblock, path, path=path, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:275, in DataLoaders.from_dblock(cls, dblock, source, path, bs, val_bs, shuffle, device, **kwargs)
#     264 @classmethod
#     265 def from_dblock(cls,
#     266     dblock, # `DataBlock` object
#    (...)
#     273     **kwargs
#     274 ):
# --> 275     return dblock.dataloaders(source, path=path, bs=bs, val_bs=val_bs, shuffle=shuffle, device=device, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/block.py:159, in DataBlock.dataloaders(self, source, path, verbose, **kwargs)
#     157 dsets = self.datasets(source, verbose=verbose)
#     158 kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
# --> 159 return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:328, in FilteredBase.dataloaders(self, bs, shuffle_train, shuffle, val_shuffle, n, path, dl_type, dl_kwargs, device, drop_last, val_bs, **kwargs)
#     326 dl = dl_type(self.subset(0), **merge(kwargs,def_kwargs, dl_kwargs[0]))
#     327 def_kwargs = {'bs':bs if val_bs is None else val_bs,'shuffle':val_shuffle,'n':None,'drop_last':False}
# --> 328 dls = [dl] + [dl.new(self.subset(i), **merge(kwargs,def_kwargs,val_kwargs,dl_kwargs[i]))
#     329               for i in range(1, self.n_subsets)]
#     330 return self._dbunch_type(*dls, path=path, device=device)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:99, in TfmdDL.new(self, dataset, cls, **kwargs)
#      97 if not hasattr(self, '_n_inp') or not hasattr(self, '_types'):
#      98     try:
# ---> 99         self._one_pass()
#     100         res._n_inp,res._types = self._n_inp,self._types
#     101     except Exception as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:82, in TfmdDL._one_pass(self)
#      80 b = self.do_batch([self.do_item(None)])
#      81 if self.device is not None: b = to_device(b, self.device)
# ---> 82 its = self.after_batch(b)
#      83 self._n_inp = 1 if not isinstance(its, (list,tuple)) or len(its)==1 else len(its)-1
#      84 self._types = explode_types(its)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:210, in Pipeline.__call__(self, o)
#     207     self.fs+=ts
#     208     self.fs = self.fs.sorted(key='order')
# --> 210 def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#     211 def __repr__(self): return f"Pipeline: {' -> '.join([f.name for f in self.fs if f.name != 'noop'])}"
#     212 def __getitem__(self,i): return self.fs[i]
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:160, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     158 for f in tfms:
#     159     if not is_enc: f = f.decode
# --> 160     x = f(x, **kwargs)
#     161 return x
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:51, in RandTransform.__call__(self, b, split_idx, **kwargs)
#      45 def __call__(self,
#      46     b,
#      47     split_idx:int=None, # Index of the train/valid dataset
#      48     **kwargs
#      49 ):
#      50     self.before_call(b, split_idx=split_idx)
# ---> 51     return super().__call__(b, split_idx=split_idx, **kwargs) if self.do else b
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:83, in Transform.__call__(self, x, **kwargs)
# ---> 83 def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:93, in Transform._call(self, fn, x, split_idx, **kwargs)
#      91 def _call(self, fn, x, split_idx=None, **kwargs):
#      92     if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 93     return self._do_call(getattr(self, fn), x, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:100, in Transform._do_call(self, f, x, **kwargs)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:100, in <genexpr>(.0)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:99, in Transform._do_call(self, f, x, **kwargs)
#      97     if f is None: return x
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
# ---> 99     return retain_type(f(x, **kwargs), x, ret)
#     100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/dispatch.py:122, in TypeDispatch.__call__(self, *args, **kwargs)
#     120 elif self.inst is not None: f = MethodType(f, self.inst)
#     121 elif self.owner is not None: f = MethodType(f, self.owner)
# --> 122 return f(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:503, in AffineCoordTfm.encodes(self, x)
#     500     coord_func = None if len(self.coord_fs)==0 or self.split_idx else partial(compose_tfms, tfms=self.coord_fs, reverse=reverse)
#     501     return x.affine_coord(self.mat, coord_func, sz=self.size, mode=mode, pad_mode=self.pad_mode, align_corners=self.align_corners)
# --> 503 def encodes(self, x:TensorImage): return self._encode(x, self.mode)
#     504 def encodes(self, x:TensorMask):  return self._encode(x, self.mode_mask)
#     505 def encodes(self, x:TensorPoint|TensorBBox): return self._encode(x, self.mode, reverse=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:501, in AffineCoordTfm._encode(self, x, mode, reverse)
#     499 def _encode(self, x, mode, reverse=False):
#     500     coord_func = None if len(self.coord_fs)==0 or self.split_idx else partial(compose_tfms, tfms=self.coord_fs, reverse=reverse)
# --> 501     return x.affine_coord(self.mat, coord_func, sz=self.size, mode=mode, pad_mode=self.pad_mode, align_corners=self.align_corners)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:392, in affine_coord(x, mat, coord_tfm, sz, mode, pad_mode, align_corners)
#     390 if mat is None: mat = _init_mat(x)[:,:2]
#     391 coords = affine_grid(mat, x.shape[:2] + size, align_corners=align_corners)
# --> 392 if coord_tfm is not None: coords = coord_tfm(coords)
#     393 return TensorImage(_grid_sample(x, coords, mode=mode, padding_mode=pad_mode, align_corners=align_corners))
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:160, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     158 for f in tfms:
#     159     if not is_enc: f = f.decode
# --> 160     x = f(x, **kwargs)
#     161 return x
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:872, in _WarpCoord.__call__(self, x, invert)
#     871 def __call__(self, x, invert=False):
# --> 872     coeffs = find_coeffs(self.targ_pts, self.orig_pts) if invert else find_coeffs(self.orig_pts, self.targ_pts)
#     873     return apply_perspective(x, coeffs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:836, in find_coeffs(p1, p2)
#     834 A = stack(m).permute(2, 0, 1)
#     835 B = p1.view(p1.shape[0], 8, 1)
# --> 836 return solve(A,B)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:819, in solve(A, B)
#     818 def solve(A,B):
# --> 819     return torch.linalg.solve(A,B)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/torch_core.py:384, in TensorBase.__torch_function__(cls, func, types, args, kwargs)
#     382 if cls.debug and func.__name__ not in ('__str__','__repr__'): print(func, types, args, kwargs)
#     383 if _torch_handled(args, cls._opt, func): types = (torch.Tensor,)
# --> 384 res = super().__torch_function__(func, types, args, ifnone(kwargs, {}))
#     385 dict_objs = _find_args(args) if args else _find_args(list(kwargs.values()))
#     386 if issubclass(type(res),TensorBase) and dict_objs: res.set_meta(dict_objs[0],as_copy=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_tensor.py:1512, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1509     return NotImplemented
#    1511 with _C.DisableTorchFunctionSubclass():
# -> 1512     ret = func(*args, **kwargs)
#    1513     if func in get_default_nowrap_functions():
#    1514         return ret
#
# NotImplementedError: The operator 'aten::_linalg_solve_ex.result' is not currently implemented for the MPS device. If you want this op to be added in priority during the prototype phase of this feature, please comment on https://github.com/pytorch/pytorch/issues/77764. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.

# %% [markdown]
# ## A ConvNeXt model

# %%
arch = 'convnext_small_in22k'

# %%
learn = train(arch, item=Resize(192, method='squish'),
              batch=aug_transforms(size=128, min_scale=0.75))
# Out:
# Could not do one pass in your dataloader, there is something wrong in it. Please see the stack trace below:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 learn = train(arch, item=Resize(192, method='squish'),
#       2               batch=aug_transforms(size=128, min_scale=0.75))
#
# Cell In[6], line 2, in train(arch, item, batch, epochs)
#       1 def train(arch, item, batch, epochs=5):
# ----> 2     dls = ImageDataLoaders.from_folder(trn_path, seed=42, valid_pct=0.2, item_tfms=item, batch_tfms=batch)
#       3     learn = vision_learner(dls, arch, metrics=error_rate).to_fp16()
#       4     learn.fine_tune(epochs, 0.01)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/data.py:125, in ImageDataLoaders.from_folder(cls, path, train, valid, valid_pct, seed, vocab, item_tfms, batch_tfms, img_cls, **kwargs)
#     118 get_items = get_image_files if valid_pct else partial(get_image_files, folders=[train, valid])
#     119 dblock = DataBlock(blocks=(ImageBlock(img_cls), CategoryBlock(vocab=vocab)),
#     120                    get_items=get_items,
#     121                    splitter=splitter,
#     122                    get_y=parent_label,
#     123                    item_tfms=item_tfms,
#     124                    batch_tfms=batch_tfms)
# --> 125 return cls.from_dblock(dblock, path, path=path, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:275, in DataLoaders.from_dblock(cls, dblock, source, path, bs, val_bs, shuffle, device, **kwargs)
#     264 @classmethod
#     265 def from_dblock(cls,
#     266     dblock, # `DataBlock` object
#    (...)
#     273     **kwargs
#     274 ):
# --> 275     return dblock.dataloaders(source, path=path, bs=bs, val_bs=val_bs, shuffle=shuffle, device=device, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/block.py:159, in DataBlock.dataloaders(self, source, path, verbose, **kwargs)
#     157 dsets = self.datasets(source, verbose=verbose)
#     158 kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
# --> 159 return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:328, in FilteredBase.dataloaders(self, bs, shuffle_train, shuffle, val_shuffle, n, path, dl_type, dl_kwargs, device, drop_last, val_bs, **kwargs)
#     326 dl = dl_type(self.subset(0), **merge(kwargs,def_kwargs, dl_kwargs[0]))
#     327 def_kwargs = {'bs':bs if val_bs is None else val_bs,'shuffle':val_shuffle,'n':None,'drop_last':False}
# --> 328 dls = [dl] + [dl.new(self.subset(i), **merge(kwargs,def_kwargs,val_kwargs,dl_kwargs[i]))
#     329               for i in range(1, self.n_subsets)]
#     330 return self._dbunch_type(*dls, path=path, device=device)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:99, in TfmdDL.new(self, dataset, cls, **kwargs)
#      97 if not hasattr(self, '_n_inp') or not hasattr(self, '_types'):
#      98     try:
# ---> 99         self._one_pass()
#     100         res._n_inp,res._types = self._n_inp,self._types
#     101     except Exception as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:82, in TfmdDL._one_pass(self)
#      80 b = self.do_batch([self.do_item(None)])
#      81 if self.device is not None: b = to_device(b, self.device)
# ---> 82 its = self.after_batch(b)
#      83 self._n_inp = 1 if not isinstance(its, (list,tuple)) or len(its)==1 else len(its)-1
#      84 self._types = explode_types(its)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:210, in Pipeline.__call__(self, o)
#     207     self.fs+=ts
#     208     self.fs = self.fs.sorted(key='order')
# --> 210 def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#     211 def __repr__(self): return f"Pipeline: {' -> '.join([f.name for f in self.fs if f.name != 'noop'])}"
#     212 def __getitem__(self,i): return self.fs[i]
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:160, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     158 for f in tfms:
#     159     if not is_enc: f = f.decode
# --> 160     x = f(x, **kwargs)
#     161 return x
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:51, in RandTransform.__call__(self, b, split_idx, **kwargs)
#      45 def __call__(self,
#      46     b,
#      47     split_idx:int=None, # Index of the train/valid dataset
#      48     **kwargs
#      49 ):
#      50     self.before_call(b, split_idx=split_idx)
# ---> 51     return super().__call__(b, split_idx=split_idx, **kwargs) if self.do else b
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:83, in Transform.__call__(self, x, **kwargs)
# ---> 83 def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:93, in Transform._call(self, fn, x, split_idx, **kwargs)
#      91 def _call(self, fn, x, split_idx=None, **kwargs):
#      92     if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 93     return self._do_call(getattr(self, fn), x, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:100, in Transform._do_call(self, f, x, **kwargs)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:100, in <genexpr>(.0)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:99, in Transform._do_call(self, f, x, **kwargs)
#      97     if f is None: return x
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
# ---> 99     return retain_type(f(x, **kwargs), x, ret)
#     100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/dispatch.py:122, in TypeDispatch.__call__(self, *args, **kwargs)
#     120 elif self.inst is not None: f = MethodType(f, self.inst)
#     121 elif self.owner is not None: f = MethodType(f, self.owner)
# --> 122 return f(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:503, in AffineCoordTfm.encodes(self, x)
#     500     coord_func = None if len(self.coord_fs)==0 or self.split_idx else partial(compose_tfms, tfms=self.coord_fs, reverse=reverse)
#     501     return x.affine_coord(self.mat, coord_func, sz=self.size, mode=mode, pad_mode=self.pad_mode, align_corners=self.align_corners)
# --> 503 def encodes(self, x:TensorImage): return self._encode(x, self.mode)
#     504 def encodes(self, x:TensorMask):  return self._encode(x, self.mode_mask)
#     505 def encodes(self, x:TensorPoint|TensorBBox): return self._encode(x, self.mode, reverse=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:501, in AffineCoordTfm._encode(self, x, mode, reverse)
#     499 def _encode(self, x, mode, reverse=False):
#     500     coord_func = None if len(self.coord_fs)==0 or self.split_idx else partial(compose_tfms, tfms=self.coord_fs, reverse=reverse)
# --> 501     return x.affine_coord(self.mat, coord_func, sz=self.size, mode=mode, pad_mode=self.pad_mode, align_corners=self.align_corners)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:392, in affine_coord(x, mat, coord_tfm, sz, mode, pad_mode, align_corners)
#     390 if mat is None: mat = _init_mat(x)[:,:2]
#     391 coords = affine_grid(mat, x.shape[:2] + size, align_corners=align_corners)
# --> 392 if coord_tfm is not None: coords = coord_tfm(coords)
#     393 return TensorImage(_grid_sample(x, coords, mode=mode, padding_mode=pad_mode, align_corners=align_corners))
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:160, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     158 for f in tfms:
#     159     if not is_enc: f = f.decode
# --> 160     x = f(x, **kwargs)
#     161 return x
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:872, in _WarpCoord.__call__(self, x, invert)
#     871 def __call__(self, x, invert=False):
# --> 872     coeffs = find_coeffs(self.targ_pts, self.orig_pts) if invert else find_coeffs(self.orig_pts, self.targ_pts)
#     873     return apply_perspective(x, coeffs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:836, in find_coeffs(p1, p2)
#     834 A = stack(m).permute(2, 0, 1)
#     835 B = p1.view(p1.shape[0], 8, 1)
# --> 836 return solve(A,B)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:819, in solve(A, B)
#     818 def solve(A,B):
# --> 819     return torch.linalg.solve(A,B)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/torch_core.py:384, in TensorBase.__torch_function__(cls, func, types, args, kwargs)
#     382 if cls.debug and func.__name__ not in ('__str__','__repr__'): print(func, types, args, kwargs)
#     383 if _torch_handled(args, cls._opt, func): types = (torch.Tensor,)
# --> 384 res = super().__torch_function__(func, types, args, ifnone(kwargs, {}))
#     385 dict_objs = _find_args(args) if args else _find_args(list(kwargs.values()))
#     386 if issubclass(type(res),TensorBase) and dict_objs: res.set_meta(dict_objs[0],as_copy=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_tensor.py:1512, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1509     return NotImplemented
#    1511 with _C.DisableTorchFunctionSubclass():
# -> 1512     ret = func(*args, **kwargs)
#    1513     if func in get_default_nowrap_functions():
#    1514         return ret
#
# NotImplementedError: The operator 'aten::_linalg_solve_ex.result' is not currently implemented for the MPS device. If you want this op to be added in priority during the prototype phase of this feature, please comment on https://github.com/pytorch/pytorch/issues/77764. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.

# %% [markdown]
# ## Preprocessing experiments

# %%
learn = train(arch, item=Resize(192),
              batch=aug_transforms(size=128, min_scale=0.75))
# Out:
# Could not do one pass in your dataloader, there is something wrong in it. Please see the stack trace below:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 learn = train(arch, item=Resize(192),
#       2               batch=aug_transforms(size=128, min_scale=0.75))
#
# Cell In[6], line 2, in train(arch, item, batch, epochs)
#       1 def train(arch, item, batch, epochs=5):
# ----> 2     dls = ImageDataLoaders.from_folder(trn_path, seed=42, valid_pct=0.2, item_tfms=item, batch_tfms=batch)
#       3     learn = vision_learner(dls, arch, metrics=error_rate).to_fp16()
#       4     learn.fine_tune(epochs, 0.01)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/data.py:125, in ImageDataLoaders.from_folder(cls, path, train, valid, valid_pct, seed, vocab, item_tfms, batch_tfms, img_cls, **kwargs)
#     118 get_items = get_image_files if valid_pct else partial(get_image_files, folders=[train, valid])
#     119 dblock = DataBlock(blocks=(ImageBlock(img_cls), CategoryBlock(vocab=vocab)),
#     120                    get_items=get_items,
#     121                    splitter=splitter,
#     122                    get_y=parent_label,
#     123                    item_tfms=item_tfms,
#     124                    batch_tfms=batch_tfms)
# --> 125 return cls.from_dblock(dblock, path, path=path, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:275, in DataLoaders.from_dblock(cls, dblock, source, path, bs, val_bs, shuffle, device, **kwargs)
#     264 @classmethod
#     265 def from_dblock(cls,
#     266     dblock, # `DataBlock` object
#    (...)
#     273     **kwargs
#     274 ):
# --> 275     return dblock.dataloaders(source, path=path, bs=bs, val_bs=val_bs, shuffle=shuffle, device=device, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/block.py:159, in DataBlock.dataloaders(self, source, path, verbose, **kwargs)
#     157 dsets = self.datasets(source, verbose=verbose)
#     158 kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
# --> 159 return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:328, in FilteredBase.dataloaders(self, bs, shuffle_train, shuffle, val_shuffle, n, path, dl_type, dl_kwargs, device, drop_last, val_bs, **kwargs)
#     326 dl = dl_type(self.subset(0), **merge(kwargs,def_kwargs, dl_kwargs[0]))
#     327 def_kwargs = {'bs':bs if val_bs is None else val_bs,'shuffle':val_shuffle,'n':None,'drop_last':False}
# --> 328 dls = [dl] + [dl.new(self.subset(i), **merge(kwargs,def_kwargs,val_kwargs,dl_kwargs[i]))
#     329               for i in range(1, self.n_subsets)]
#     330 return self._dbunch_type(*dls, path=path, device=device)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:99, in TfmdDL.new(self, dataset, cls, **kwargs)
#      97 if not hasattr(self, '_n_inp') or not hasattr(self, '_types'):
#      98     try:
# ---> 99         self._one_pass()
#     100         res._n_inp,res._types = self._n_inp,self._types
#     101     except Exception as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:82, in TfmdDL._one_pass(self)
#      80 b = self.do_batch([self.do_item(None)])
#      81 if self.device is not None: b = to_device(b, self.device)
# ---> 82 its = self.after_batch(b)
#      83 self._n_inp = 1 if not isinstance(its, (list,tuple)) or len(its)==1 else len(its)-1
#      84 self._types = explode_types(its)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:210, in Pipeline.__call__(self, o)
#     207     self.fs+=ts
#     208     self.fs = self.fs.sorted(key='order')
# --> 210 def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#     211 def __repr__(self): return f"Pipeline: {' -> '.join([f.name for f in self.fs if f.name != 'noop'])}"
#     212 def __getitem__(self,i): return self.fs[i]
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:160, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     158 for f in tfms:
#     159     if not is_enc: f = f.decode
# --> 160     x = f(x, **kwargs)
#     161 return x
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:51, in RandTransform.__call__(self, b, split_idx, **kwargs)
#      45 def __call__(self,
#      46     b,
#      47     split_idx:int=None, # Index of the train/valid dataset
#      48     **kwargs
#      49 ):
#      50     self.before_call(b, split_idx=split_idx)
# ---> 51     return super().__call__(b, split_idx=split_idx, **kwargs) if self.do else b
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:83, in Transform.__call__(self, x, **kwargs)
# ---> 83 def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:93, in Transform._call(self, fn, x, split_idx, **kwargs)
#      91 def _call(self, fn, x, split_idx=None, **kwargs):
#      92     if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 93     return self._do_call(getattr(self, fn), x, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:100, in Transform._do_call(self, f, x, **kwargs)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:100, in <genexpr>(.0)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:99, in Transform._do_call(self, f, x, **kwargs)
#      97     if f is None: return x
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
# ---> 99     return retain_type(f(x, **kwargs), x, ret)
#     100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/dispatch.py:122, in TypeDispatch.__call__(self, *args, **kwargs)
#     120 elif self.inst is not None: f = MethodType(f, self.inst)
#     121 elif self.owner is not None: f = MethodType(f, self.owner)
# --> 122 return f(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:503, in AffineCoordTfm.encodes(self, x)
#     500     coord_func = None if len(self.coord_fs)==0 or self.split_idx else partial(compose_tfms, tfms=self.coord_fs, reverse=reverse)
#     501     return x.affine_coord(self.mat, coord_func, sz=self.size, mode=mode, pad_mode=self.pad_mode, align_corners=self.align_corners)
# --> 503 def encodes(self, x:TensorImage): return self._encode(x, self.mode)
#     504 def encodes(self, x:TensorMask):  return self._encode(x, self.mode_mask)
#     505 def encodes(self, x:TensorPoint|TensorBBox): return self._encode(x, self.mode, reverse=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:501, in AffineCoordTfm._encode(self, x, mode, reverse)
#     499 def _encode(self, x, mode, reverse=False):
#     500     coord_func = None if len(self.coord_fs)==0 or self.split_idx else partial(compose_tfms, tfms=self.coord_fs, reverse=reverse)
# --> 501     return x.affine_coord(self.mat, coord_func, sz=self.size, mode=mode, pad_mode=self.pad_mode, align_corners=self.align_corners)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:392, in affine_coord(x, mat, coord_tfm, sz, mode, pad_mode, align_corners)
#     390 if mat is None: mat = _init_mat(x)[:,:2]
#     391 coords = affine_grid(mat, x.shape[:2] + size, align_corners=align_corners)
# --> 392 if coord_tfm is not None: coords = coord_tfm(coords)
#     393 return TensorImage(_grid_sample(x, coords, mode=mode, padding_mode=pad_mode, align_corners=align_corners))
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:160, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     158 for f in tfms:
#     159     if not is_enc: f = f.decode
# --> 160     x = f(x, **kwargs)
#     161 return x
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:872, in _WarpCoord.__call__(self, x, invert)
#     871 def __call__(self, x, invert=False):
# --> 872     coeffs = find_coeffs(self.targ_pts, self.orig_pts) if invert else find_coeffs(self.orig_pts, self.targ_pts)
#     873     return apply_perspective(x, coeffs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:836, in find_coeffs(p1, p2)
#     834 A = stack(m).permute(2, 0, 1)
#     835 B = p1.view(p1.shape[0], 8, 1)
# --> 836 return solve(A,B)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:819, in solve(A, B)
#     818 def solve(A,B):
# --> 819     return torch.linalg.solve(A,B)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/torch_core.py:384, in TensorBase.__torch_function__(cls, func, types, args, kwargs)
#     382 if cls.debug and func.__name__ not in ('__str__','__repr__'): print(func, types, args, kwargs)
#     383 if _torch_handled(args, cls._opt, func): types = (torch.Tensor,)
# --> 384 res = super().__torch_function__(func, types, args, ifnone(kwargs, {}))
#     385 dict_objs = _find_args(args) if args else _find_args(list(kwargs.values()))
#     386 if issubclass(type(res),TensorBase) and dict_objs: res.set_meta(dict_objs[0],as_copy=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_tensor.py:1512, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1509     return NotImplemented
#    1511 with _C.DisableTorchFunctionSubclass():
# -> 1512     ret = func(*args, **kwargs)
#    1513     if func in get_default_nowrap_functions():
#    1514         return ret
#
# NotImplementedError: The operator 'aten::_linalg_solve_ex.result' is not currently implemented for the MPS device. If you want this op to be added in priority during the prototype phase of this feature, please comment on https://github.com/pytorch/pytorch/issues/77764. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.

# %%
dls = ImageDataLoaders.from_folder(trn_path, valid_pct=0.2, seed=42,
    item_tfms=Resize(192, method=ResizeMethod.Pad, pad_mode=PadMode.Zeros))
dls.show_batch(max_n=3)

# %%
learn = train(arch, item=Resize((256,192), method=ResizeMethod.Pad, pad_mode=PadMode.Zeros),
      batch=aug_transforms(size=(171,128), min_scale=0.75))
# Out:
# Could not do one pass in your dataloader, there is something wrong in it. Please see the stack trace below:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 learn = train(arch, item=Resize((256,192), method=ResizeMethod.Pad, pad_mode=PadMode.Zeros),
#       2       batch=aug_transforms(size=(171,128), min_scale=0.75))
#
# Cell In[6], line 2, in train(arch, item, batch, epochs)
#       1 def train(arch, item, batch, epochs=5):
# ----> 2     dls = ImageDataLoaders.from_folder(trn_path, seed=42, valid_pct=0.2, item_tfms=item, batch_tfms=batch)
#       3     learn = vision_learner(dls, arch, metrics=error_rate).to_fp16()
#       4     learn.fine_tune(epochs, 0.01)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/data.py:125, in ImageDataLoaders.from_folder(cls, path, train, valid, valid_pct, seed, vocab, item_tfms, batch_tfms, img_cls, **kwargs)
#     118 get_items = get_image_files if valid_pct else partial(get_image_files, folders=[train, valid])
#     119 dblock = DataBlock(blocks=(ImageBlock(img_cls), CategoryBlock(vocab=vocab)),
#     120                    get_items=get_items,
#     121                    splitter=splitter,
#     122                    get_y=parent_label,
#     123                    item_tfms=item_tfms,
#     124                    batch_tfms=batch_tfms)
# --> 125 return cls.from_dblock(dblock, path, path=path, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:275, in DataLoaders.from_dblock(cls, dblock, source, path, bs, val_bs, shuffle, device, **kwargs)
#     264 @classmethod
#     265 def from_dblock(cls,
#     266     dblock, # `DataBlock` object
#    (...)
#     273     **kwargs
#     274 ):
# --> 275     return dblock.dataloaders(source, path=path, bs=bs, val_bs=val_bs, shuffle=shuffle, device=device, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/block.py:159, in DataBlock.dataloaders(self, source, path, verbose, **kwargs)
#     157 dsets = self.datasets(source, verbose=verbose)
#     158 kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
# --> 159 return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:328, in FilteredBase.dataloaders(self, bs, shuffle_train, shuffle, val_shuffle, n, path, dl_type, dl_kwargs, device, drop_last, val_bs, **kwargs)
#     326 dl = dl_type(self.subset(0), **merge(kwargs,def_kwargs, dl_kwargs[0]))
#     327 def_kwargs = {'bs':bs if val_bs is None else val_bs,'shuffle':val_shuffle,'n':None,'drop_last':False}
# --> 328 dls = [dl] + [dl.new(self.subset(i), **merge(kwargs,def_kwargs,val_kwargs,dl_kwargs[i]))
#     329               for i in range(1, self.n_subsets)]
#     330 return self._dbunch_type(*dls, path=path, device=device)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:99, in TfmdDL.new(self, dataset, cls, **kwargs)
#      97 if not hasattr(self, '_n_inp') or not hasattr(self, '_types'):
#      98     try:
# ---> 99         self._one_pass()
#     100         res._n_inp,res._types = self._n_inp,self._types
#     101     except Exception as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/data/core.py:82, in TfmdDL._one_pass(self)
#      80 b = self.do_batch([self.do_item(None)])
#      81 if self.device is not None: b = to_device(b, self.device)
# ---> 82 its = self.after_batch(b)
#      83 self._n_inp = 1 if not isinstance(its, (list,tuple)) or len(its)==1 else len(its)-1
#      84 self._types = explode_types(its)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:210, in Pipeline.__call__(self, o)
#     207     self.fs+=ts
#     208     self.fs = self.fs.sorted(key='order')
# --> 210 def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#     211 def __repr__(self): return f"Pipeline: {' -> '.join([f.name for f in self.fs if f.name != 'noop'])}"
#     212 def __getitem__(self,i): return self.fs[i]
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:160, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     158 for f in tfms:
#     159     if not is_enc: f = f.decode
# --> 160     x = f(x, **kwargs)
#     161 return x
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:51, in RandTransform.__call__(self, b, split_idx, **kwargs)
#      45 def __call__(self,
#      46     b,
#      47     split_idx:int=None, # Index of the train/valid dataset
#      48     **kwargs
#      49 ):
#      50     self.before_call(b, split_idx=split_idx)
# ---> 51     return super().__call__(b, split_idx=split_idx, **kwargs) if self.do else b
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:83, in Transform.__call__(self, x, **kwargs)
# ---> 83 def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:93, in Transform._call(self, fn, x, split_idx, **kwargs)
#      91 def _call(self, fn, x, split_idx=None, **kwargs):
#      92     if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 93     return self._do_call(getattr(self, fn), x, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:100, in Transform._do_call(self, f, x, **kwargs)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:100, in <genexpr>(.0)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:99, in Transform._do_call(self, f, x, **kwargs)
#      97     if f is None: return x
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
# ---> 99     return retain_type(f(x, **kwargs), x, ret)
#     100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/dispatch.py:122, in TypeDispatch.__call__(self, *args, **kwargs)
#     120 elif self.inst is not None: f = MethodType(f, self.inst)
#     121 elif self.owner is not None: f = MethodType(f, self.owner)
# --> 122 return f(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:503, in AffineCoordTfm.encodes(self, x)
#     500     coord_func = None if len(self.coord_fs)==0 or self.split_idx else partial(compose_tfms, tfms=self.coord_fs, reverse=reverse)
#     501     return x.affine_coord(self.mat, coord_func, sz=self.size, mode=mode, pad_mode=self.pad_mode, align_corners=self.align_corners)
# --> 503 def encodes(self, x:TensorImage): return self._encode(x, self.mode)
#     504 def encodes(self, x:TensorMask):  return self._encode(x, self.mode_mask)
#     505 def encodes(self, x:TensorPoint|TensorBBox): return self._encode(x, self.mode, reverse=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:501, in AffineCoordTfm._encode(self, x, mode, reverse)
#     499 def _encode(self, x, mode, reverse=False):
#     500     coord_func = None if len(self.coord_fs)==0 or self.split_idx else partial(compose_tfms, tfms=self.coord_fs, reverse=reverse)
# --> 501     return x.affine_coord(self.mat, coord_func, sz=self.size, mode=mode, pad_mode=self.pad_mode, align_corners=self.align_corners)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:392, in affine_coord(x, mat, coord_tfm, sz, mode, pad_mode, align_corners)
#     390 if mat is None: mat = _init_mat(x)[:,:2]
#     391 coords = affine_grid(mat, x.shape[:2] + size, align_corners=align_corners)
# --> 392 if coord_tfm is not None: coords = coord_tfm(coords)
#     393 return TensorImage(_grid_sample(x, coords, mode=mode, padding_mode=pad_mode, align_corners=align_corners))
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastcore/transform.py:160, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     158 for f in tfms:
#     159     if not is_enc: f = f.decode
# --> 160     x = f(x, **kwargs)
#     161 return x
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:872, in _WarpCoord.__call__(self, x, invert)
#     871 def __call__(self, x, invert=False):
# --> 872     coeffs = find_coeffs(self.targ_pts, self.orig_pts) if invert else find_coeffs(self.orig_pts, self.targ_pts)
#     873     return apply_perspective(x, coeffs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:836, in find_coeffs(p1, p2)
#     834 A = stack(m).permute(2, 0, 1)
#     835 B = p1.view(p1.shape[0], 8, 1)
# --> 836 return solve(A,B)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/vision/augment.py:819, in solve(A, B)
#     818 def solve(A,B):
# --> 819     return torch.linalg.solve(A,B)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fastai/torch_core.py:384, in TensorBase.__torch_function__(cls, func, types, args, kwargs)
#     382 if cls.debug and func.__name__ not in ('__str__','__repr__'): print(func, types, args, kwargs)
#     383 if _torch_handled(args, cls._opt, func): types = (torch.Tensor,)
# --> 384 res = super().__torch_function__(func, types, args, ifnone(kwargs, {}))
#     385 dict_objs = _find_args(args) if args else _find_args(list(kwargs.values()))
#     386 if issubclass(type(res),TensorBase) and dict_objs: res.set_meta(dict_objs[0],as_copy=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_tensor.py:1512, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1509     return NotImplemented
#    1511 with _C.DisableTorchFunctionSubclass():
# -> 1512     ret = func(*args, **kwargs)
#    1513     if func in get_default_nowrap_functions():
#    1514         return ret
#
# NotImplementedError: The operator 'aten::_linalg_solve_ex.result' is not currently implemented for the MPS device. If you want this op to be added in priority during the prototype phase of this feature, please comment on https://github.com/pytorch/pytorch/issues/77764. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.

# %% [markdown]
# ## Test time augmentation

# %%
valid = learn.dls.valid
preds,targs = learn.get_preds(dl=valid)

# %%
error_rate(preds, targs)

# %%
learn.dls.train.show_batch(max_n=6, unique=True)

# %%
tta_preds,_ = learn.tta(dl=valid)

# %%
error_rate(tta_preds, targs)

# %% [markdown]
# ## Scaling up

# %%
trn_path = path/'train_images'

# %%
learn = train(arch, epochs=12,
              item=Resize((480, 360), method=ResizeMethod.Pad, pad_mode=PadMode.Zeros),
              batch=aug_transforms(size=(256,192), min_scale=0.75))

# %%
tta_preds,targs = learn.tta(dl=learn.dls.valid)
error_rate(tta_preds, targs)

# %% [markdown]
# ## Submission

# %%
tst_files = get_image_files(path/'test_images').sorted()
tst_dl = learn.dls.test_dl(tst_files)

# %%
preds,_ = learn.tta(dl=tst_dl)

# %%
idxs = preds.argmax(dim=1)

# %%
vocab = np.array(learn.dls.vocab)
results = pd.Series(vocab[idxs], name="idxs")

# %%
ss = pd.read_csv(path/'sample_submission.csv')
ss['label'] = results
ss.to_csv('subm.csv', index=False)
# !head subm.csv

# %%
if not iskaggle:
    from kaggle import api
    api.competition_submit_cli('subm.csv', 'convnext small 256x192 12 epochs tta', comp)

# %%
# This is what I use to push my notebook from my home PC to Kaggle

if not iskaggle:
    push_notebook('jhoward', 'small-models-road-to-the-top-part-2',
                  title='Small models: Road to the Top, Part 2',
                  file='small-models-road-to-the-top-part-2.ipynb',
                  competition=comp, private=True, gpu=True)

# %% [markdown]
# ## Conclusion
